# %% [markdown]
# # Step 1 - Install the required dependencies and make sure the python version is 3.10 and above

# %%
import sys
print(sys.executable)
# Out:
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/bin/python

# %%
# !pip install zenoml
# Out:
# Requirement already satisfied: zenoml in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (0.6.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (2.3.3)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (1.6.0)
# Requirement already satisfied: setuptools in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (65.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (2.32.5)
# Requirement already satisfied: zeno-sliceline<0.0.2,>=0.0.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (0.0.1)
# Requirement already satisfied: pathos<0.4.0,>=0.3.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (0.3.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (4.67.1)
# Requirement already satisfied: inquirer<4.0.0,>=3.1.2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (3.4.1)
# Requirement already satisfied: pydantic<2.0.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (1.10.24)
# Requirement already satisfied: fastapi<0.101.0,>=0.95.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (0.100.1)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (2.3.0)
# Requirement already satisfied: websockets<12.0,>=11.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (11.0.3)
# Requirement already satisfied: opentsne<1.1.0,>=0.7.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (1.0.4)
# Requirement already satisfied: uvicorn<0.24,>=0.22 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zenoml) (0.23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from fastapi<0.101.0,>=0.95.1->zenoml) (4.15.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from fastapi<0.101.0,>=0.95.1->zenoml) (0.27.0)
# Requirement already satisfied: blessed>=1.19.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from inquirer<4.0.0,>=3.1.2->zenoml) (1.25.0)
# Requirement already satisfied: readchar>=4.2.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from inquirer<4.0.0,>=3.1.2->zenoml) (4.2.1)
# Requirement already satisfied: editor>=1.6.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from inquirer<4.0.0,>=3.1.2->zenoml) (1.6.6)
# Requirement already satisfied: scipy in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from opentsne<1.1.0,>=0.7.1->zenoml) (1.15.3)
# Requirement already satisfied: numpy>=1.16.6 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from opentsne<1.1.0,>=0.7.1->zenoml) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from opentsne<1.1.0,>=0.7.1->zenoml) (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas<3.0.0,>=2.0.0->zenoml) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas<3.0.0,>=2.0.0->zenoml) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas<3.0.0,>=2.0.0->zenoml) (2025.2)
# Requirement already satisfied: pox>=0.3.6 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (0.3.6)
# Requirement already satisfied: ppft>=1.7.7 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (1.7.7)
# Requirement already satisfied: multiprocess>=0.70.18 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (0.70.18)
# Requirement already satisfied: dill>=0.4.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (2025.10.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (2.5.0)
# Requirement already satisfied: h11>=0.8 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from uvicorn<0.24,>=0.22->zenoml) (0.16.0)
# Requirement already satisfied: click>=7.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from uvicorn<0.24,>=0.22->zenoml) (8.3.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from blessed>=1.19.0->inquirer<4.0.0,>=3.1.2->zenoml) (0.2.14)
# Requirement already satisfied: xmod in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from editor>=1.6.0->inquirer<4.0.0,>=3.1.2->zenoml) (1.8.1)
# Requirement already satisfied: runs in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from editor>=1.6.0->inquirer<4.0.0,>=3.1.2->zenoml) (1.2.2)
# Requirement already satisfied: six>=1.5 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->zenoml) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from scikit-learn>=0.20->opentsne<1.1.0,>=0.7.1->zenoml) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from scikit-learn>=0.20->opentsne<1.1.0,>=0.7.1->zenoml) (1.5.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.101.0,>=0.95.1->zenoml) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.101.0,>=0.95.1->zenoml) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.101.0,>=0.95.1->zenoml) (1.3.1)
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install datasets
# !pip install transformers
# !pip install tqdm
# !pip install torch
# Out:
# Requirement already satisfied: datasets in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (4.4.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: requests>=2.32.2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: fsspec[http]<=2025.10.0,>=2023.1.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (2025.10.0)
# Requirement already satisfied: numpy>=1.17 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: xxhash in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: filelock in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (3.20.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: packaging in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (25.0)
# Requirement already satisfied: pandas in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: httpcore==1.* in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: anyio in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: idna in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: certifi in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: h11>=0.16 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: six>=1.5 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: transformers in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (4.57.1)
# Requirement already satisfied: requests in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: packaging>=20.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (25.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: numpy>=1.17 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: filelock in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from transformers) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->transformers) (3.11)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: tqdm in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (4.67.1)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: torch in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (2.9.1)
# Requirement already satisfied: filelock in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch) (3.20.0)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# WARNING: There was an error checking the latest version of pip.

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# # Step 2 - Load a dataset from Hugging Face

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset("cardiffnlp/tweet_eval", "sentiment")
df = pd.DataFrame(ds['test']).head(500)
df.head(5)
# Out:
#                                                 text  label
# 0  @user @user what do these '1/2 naked pics' hav...      1
# 1  OH: “I had a blue penis while I was this” [pla...      1
# 2  @user @user That's coming, but I think the vic...      1
# 3  I think I may be finally in with the in crowd ...      2
# 4  @user Wow,first Hugo Chavez and now Fidel Cast...      0

# %%
def label_map(x):
    if x == 0:
        return 'negative'
    elif x == 1:
        return 'neutral'
    elif x == 2:
        return 'positive'
    return x
df['label'] = df['label'].map(label_map)

# %% [markdown]
# # Step 3 - Run model inference

# %% [markdown]
# Warning: This step is going to download two models of ~500MB each.
#
# **If you don't want to download the models, you can jump to step 4 and use the provided data in the repo instead.**

# %% [markdown]
# ### Run inference with roberta

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

# %%
import tqdm

results = []
texts = df['text'].to_list()

## Depending on your machine, this should take around 1 minute
for text in tqdm.tqdm(texts):
    results.append(pipe(text))
# Out:
# 100%|█████████████████████████████████████████| 500/500 [00:08<00:00, 60.71it/s]

# %%
#!pip uninstall torch torchvision torchaudio

# %%
df['roberta'] = [r[0]['label'] for r in results]
df['roberta_score'] = [r[0]['score'] for r in results]

# %% [markdown]
# ### Run inference with gpt2

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="LYTinn/finetuning-sentiment-model-tweet-gpt2")
# Out:
# Device set to use mps:0

# %%
import tqdm

results = []
texts = df['text'].to_list()

## Depending on your machine, this should take around 1 minute
for text in tqdm.tqdm(texts):
    results.append(pipe(text))
# Out:
# 100%|█████████████████████████████████████████| 500/500 [00:06<00:00, 73.28it/s]

# %%
df['gpt2'] = [r[0]['label'] for r in results]
df['gpt2_score'] = [r[0]['score'] for r in results]

## map labels back
def label_map(x):
    if x == 'LABEL_0':
        return 'negative'
    elif x == 'LABEL_1':
        return 'neutral'
    elif x == 'LABEL_2':
        return 'positive'
    return x
df['gpt2'] = df['gpt2'].map(label_map)

# %% [markdown]
# # Step 4 - Pre-processing data and add additional columns

# %%
## If you skip the model inference, uncomment the code below and load the provided data

# df = pd.read_csv('tweets.csv')

# %%
df["input_length"] = df["text"].str.len()

# %% [markdown]
# # Step 5 - Start Zeno for interactive slicing
#
# In this step, you need to create 5 slices in the Zeno interface and derive meaningful insights.
#
# As a starting point, try to create the two slices we provide:
#
# 1. Tweets with hashtags
# 2. Tweets with strong positive words (e.g., love) -- you can determine the exact words

# %% [markdown]
# Creating slices in Zeno is straightforward: Just click on the '+' button for 'create a new slice', and you can define the slice using existing column attributes, with simple value macthing or even regular expression.
#
# ![image.png](images/image.png)
#
# There are more fun features in Zeno, including interactive metadata & model comparison -- feel free to check the teaser video in [README](https://github.com/zeno-ml/zeno) of the Zeno repository.

# %%
## Execute the code here to start a local Zeno server

from zeno import zeno

from zeno.api import model, distill, metric
from zeno.api import ModelReturn, MetricReturn, DistillReturn, ZenoOptions

@model
def load_model(model_name):
    
    def pred(df, ops: ZenoOptions):
        out = df[model_name]
        return ModelReturn(model_output=out)

    return pred

@distill
def label_match(df, ops: ZenoOptions):
    results = (df[ops.label_column] == df[ops.output_column]).to_list()
    return DistillReturn(distill_output=results)

@metric
def accuracy(df, ops: ZenoOptions):
    avg = df[ops.distill_columns["label_match"]].mean()
    return MetricReturn(metric=avg)

zeno({
    "metadata": df, # Pandas DataFrame with a row for each instance
    "view": "text-classification", # The type of view for this data/task
    "data_column": "text", 
    "label_column": "label",
    "functions": [load_model, label_match, accuracy],
    "models": ["roberta", "gpt2"],
    "port": 8231
})
# Out:
# WARNING: no id_column specified, using index as id_column. If you are using a data_column, suggest using it as id_column.
# Running predistill functions
# Zeno running on http://localhost:8231
#
#
# Running inference
# Running postdistill functions
# Done processing
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 178, in get_metrics_for_slices
#     return zeno.get_metrics_for_slices(req.metric_keys, req.filter_ids)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 478, in get_metrics_for_slices
#     metric = self.calculate_metric(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 247, in run_asgi
#     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 149, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 149, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 341, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 82, in app
#     await func(session)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 324, in app
#     await dependant.call(**values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 232, in results_websocket
#     await asyncio.sleep(1)
#   File "/Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py", line 605, in sleep
#     return await future
# asyncio.exceptions.CancelledError
# ERROR:    Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 686, in lifespan
#     await receive()
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#   File "/Users/lawrenceegharevba/.pyenv/versions/3.10.12/lib/python3.10/asyncio/queues.py", line 159, in get
#     await getter
# asyncio.exceptions.CancelledError

# %% [markdown]
# After running the code above, you should be able to access Zeno in http://localhost:8231

# %% [markdown]
# After successfully creating the two slices, come up with three *additional* slices you want to check and **create** the slices in the Zeno interface.
#
# There are two directions to identify useful slices:
# - Top-down: Think about what kinds of things the model can struggle with, and come up with some slices.
# - Bottom-up: Look at model (mis-)predictions, come up with hypotheses, and translate them into data slices.
#
# 3. [YOUR CHOICE]
# 4. [YOUR CHOICE]
# 5. [YOUR CHOICE]

# %%
## Write down descriptions of additional slices you created

custom_slice_descriptions = [
    "",
]

# %% [markdown]
# # Slice Evaluation (Pre-LLM Generated Examples)
#
# | Slice Name               | Rationale                                                                 | Observation                                                                                         | Implication                                                                                   |
# |---------------------------|---------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------|
# | Positive Label (Tweets)   | Hypothesis is that the model should perform strongly on clearly positive sentiment, since training data often has abundant positive examples. | Accuracy is high (~70%). Predictions were consistent, though occasionally tweets with sarcasm (“love waiting in traffic”) were misclassified. | Model is strong at detecting explicit positivity, but sarcasm or subtle positivity can cause errors. |
# | Negative Tweets           | Hypothesis was that tweets with negative cues (cancel, criticism, decline) would be harder for the model. | Accuracy dropped to 0.60. Misclassifications clustered around sarcasm, political critique, and factual decline statements. | Model struggles with subtle negativity and context, defaulting to neutral or misreading factual decline as sentiment. |
# | Long Tweets               | Longer tweets may introduce ambiguity or mixed sentiment, challenging the model. | Accuracy = 0.70. Misclassifications clustered around political critique, sarcasm, and factual decline statements. Clear sentiment tweets were correctly classified. | Model struggles with nuanced language in long tweets, defaulting to neutral or misinterpreting factual tone as sentiment. |
# | Low Confidence Predictions | Hypothesis was that low confidence scores indicate ambiguous or difficult cases. | Accuracy = 0.55. Misclassifications clustered around emotional nuance, sarcasm, factual critique, and political framing. Correct predictions were mostly straightforward neutral or strongly negative tweets. | Confidence scores are a useful diagnostic — low confidence reliably flags examples where the model is unstable or error prone. |
# | Ambiguous Tweets          | Hypothesis was that evaluative phrasing (“cozied up”) should be classified as negative. | Model predicted neutral, showing a misclassification. | The model underestimates subtle negative sentiment in political contexts. |

# %% [markdown]
# # Step 6 - Write down three addition data slices you want to create but do not have the metadata for slicing

# %% [markdown]
# In the previous step, you might have already come up with some slices you wanted to create but found it hard to do with existing metadata. Write down three of such slices in this step.
#
# Example:
# - I want to create a slice on tweets using slangs
# - I want to create a slice on non-English tweets (if any)

# %% [raw]
# ## Write down three additional data slices here:
#
# additional_slice_descriptions = [
#     "I want to create a slice on tweets using emoji
#
#     want to create a slice on tweets using slang,
#
#     want to create a slice on tweets using question tweets",
# ]

# %% [markdown]
# # Step 7 - Generate more test cases with Large Language Models

# %% [markdown]
# Select one slice from the three you wrote down and generate **10 test cases** using LLMs, which can include average case, boundary case, or difficult case.
#
# Your input can be in the following format:
#
# > Examples:
# > - OH: “I had a blue penis while I was this” [playing with Google Earth VR]
# > - @user @user That’s coming, but I think the victims are going to be Medicaid recipients.
# > - I think I may be finally in with the in crowd #mannequinchallenge  #grads2014 @user
# >
# > Generate more tweets using slangs.
#
# The first part of **Examples** conditions the LLM on the style, length, and content of examples. The second part of **Instructions** instructs what kind of examples you want LLM to generate.
#
# Use our provided GPTs to start the task: [llm-based-test-case-generator](https://chatgpt.com/g/g-982cylVn2-llm-based-test-case-generator). If you do not have access to GPTs, use the plain ChatGPT or other LLM providers you have access to instead.

# %% [markdown]
# ## Write down the slice you select
#
# slice_description = "Rationale
#
# •	Emojis often carry sentiment (😂 = positive, 😭 = negative/sad, 😡 = anger).
#
# •	Hypothesis: The model may misclassify tweets where emojis contradict or amplify the text sentiment.
# "
#
# ## Write down all generated test cases here
#
# generated_test_cases = [
#
# 1.	“Best day ever 😂😂😂” → Positive
#
# 2.	“I can’t believe this happened 😭” → Negative
#
# 3.	“Another Monday… 😒” → Negative
#
# 4.	“So proud of my team 🎉” → Positive
#
# 5.	“That exam was brutal 😡” → Negative
#
# 6.	“Finally finished my project 🙌” → Positive
#
# 7.	“I guess it’s fine… 🤷” → Neutral
#
# 8.	“Love this song ❤️” → Positive
#
# 9.	“Traffic again… ugh 😩” → Negative
#
# 10.	“Not sure what to think 🤔” → Neutral",
# ]

# %% [markdown]
# # Add LLM-Generated test cases (dataset) to Zeno

# %%
# Add LLM-Generated dataset to Zeno
texts = [
    "Best day ever 😂😂😂",
    "I can’t believe this happened 😭",
    "Another Monday… 😒",
    "So proud of my team 🎉",
    "That exam was brutal 😡",
    "Finally finished my project 🙌",
    "I guess it’s fine… 🤷",
    "Love this song ❤️",
    "Traffic again… ugh 😩",
    "Not sure what to think 🤔",
]

gold_labels = [
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "neutral",
    "positive",
    "negative",
    "neutral",
]

outputs = pipe(texts)
pred_labels = [o["label"] for o in outputs]

new_data = pd.DataFrame({
    "text": texts,
    "label": gold_labels,
    "prediction": pred_labels,
})
new_data["correct"] = (new_data["label"] == new_data["prediction"]).astype(int)

# %%
outputs = pipe(new_data["text"].tolist())
new_data["prediction"] = [o["label"] for o in outputs]
new_data["correct"] = (new_data["label"] == new_data["prediction"]).astype(int)

# %%
all_outputs = pipe(df_extended["text"].tolist())
df_extended["roberta"] = [o["label"] for o in all_outputs]

# %%
zeno({
    "metadata": df_extended,
    "view": "text-classification",
    "data_column": "text",
    "label_column": "label",
    "functions": [load_model, label_match, accuracy],
    "models": ["roberta"],  # or ["roberta", "gpt2"] if you also have that column
    "port": 8231
})
# Out:
# WARNING: no id_column specified, using index as id_column. If you are using a data_column, suggest using it as id_column.
#
# Zeno running on http://localhost:8231
# Running predistill functions
#
# Running inference
# Inference on roberta: 100%|███████████████████| 10/10 [00:00<00:00, 1367.07it/s]
# Running postdistill functions
# postprocessing label_match on roberta: 100%|███| 10/10 [00:00<00:00, 829.88it/s]
# Done processing
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 247, in run_asgi
#     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 149, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 149, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 341, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 82, in app
#     await func(session)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 324, in app
#     await dependant.call(**values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 235, in results_websocket
#     await websocket.send_json(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/websockets.py", line 173, in send_json
#     await self.send({"type": "websocket.send", "text": text})
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/websockets.py", line 85, in send
#     await self._send(message)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 65, in sender
#     await send(message)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 65, in sender
#     await send(message)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 320, in asgi_send
#     await self.send(data)  # type: ignore[arg-type]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/websockets/legacy/protocol.py", line 635, in send
#     await self.ensure_open()
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/websockets/legacy/protocol.py", line 935, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedOK: received 1001 (going away); then sent 1001 (going away)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
# ...
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/mx/0stgg0m56051q1f81rpvwskw0000gn/T/ipykernel_86357/1105304987.py", line 25, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# Process ForkPoolWorker-4:8:
# Process ForkPoolWorker-4:10:
# Process ForkPoolWorker-4:7:
# Process ForkPoolWorker-4:3:
# Process ForkPoolWorker-4:5:
# Process ForkPoolWorker-4:6:
# Process ForkPoolWorker-4:4:
# Process ForkPoolWorker-4:1:
# Process ForkPoolWorker-4:2:
# Process ForkPoolWorker-4:9:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lawrenceegharevba/mlip_labs/cmu-mlip-model-testing-lab/venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)

# %% [markdown]
# # Slice Evaluation (Post-LLM Generated Examples)

# %% [markdown]
# | Slice Name              | Rationale                                                                 | Observed Behavior                                                                                   | Implication                                                                                   |
# |--------------------------|---------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------|
# | Positive Label Tweets    | Explicitly positive tweets, often with praise, enthusiasm, or supportive tone | Accuracy ≈ 0.95 (20 instances). Model correctly classified clear positive sentiment (e.g., praise, celebration, emoji reinforcement). Occasional misclassifications occurred with sarcasm or subtle positivity. | Model is strong at detecting explicit positivity, especially when reinforced by emojis or hashtags. Weaknesses remain in subtle or sarcastic positive phrasing. |
# | Negative Tweets          | Explicitly negative tweets with strong language                          | Accuracy ≈ 0.60 (20 instances). Model correctly classified clear negativity, but struggled with sarcasm and factual decline. | Model handles explicit negativity well but misclassifies subtle or implied negative sentiment. |
# | Long Tweets              | Longer tweets often contain multiple clauses, sarcasm, or mixed sentiment | Accuracy ≈ 0.60 (20 instances). Misclassifications clustered around sarcasm, factual decline, missed enthusiasm, and emoji cues. | Model struggles with nuanced or multi‑clause sentiment in long tweets.                        |
# | Low Confidence Predictions | Tweets flagged with low model confidence scores                         | Accuracy ≈ 0.55–0.60 (20 instances). Misclassifications clustered around sarcasm, factual decline, missed enthusiasm, and emoji cues. | Confidence scores reliably highlight unstable predictions, useful for human‑in‑the‑loop review. |
# | Ambiguous Tweets         | Tweets with unclear sentiment, sarcasm, rhetorical questions, or factual tone | Accuracy ≈ 0.70 (20 instances). Misclassifications clustered around sarcasm, factual decline, promotional tone, and ambiguous emoji use. | Model struggles with ambiguity, often defaulting to neutral or misreading tone.                |
# | Slang Tweets             | Tweets with slang, informal phrasing, or culturally loaded hashtags        | Accuracy ≈ 0.71 (20 instances). Correct on slang‑reinforced praise/criticism, but misclassified slang terms, promotional tone, and rhetorical critiques. | Model struggles with informal or culturally specific slang, often misinterpreting tone.        |
# | Emoji Tweets             | Emojis often carry sentiment signals that may reinforce or contradict text | Accuracy = 1.00 (20 instances). Model correctly classified positive, negative, and sarcastic emoji cases. | Model distinguishes emoji sentiment in context, but more diverse emoji testing is needed.      |
# | Question Tweets          | Tweets ending with or containing questions, often rhetorical or sarcastic | Accuracy ≈ 0.66 (20 instances). Correct on explicit negative rhetorical questions, but misclassified neutral/factual inquiries and emoji‑laden questions. | Model struggles with distinguishing genuine inquiries from rhetorical or sarcastic sentiment.  |
